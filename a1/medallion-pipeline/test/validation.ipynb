# %%
from pyspark.sql import SparkSession

# 创建Spark会话
spark = SparkSession.builder \
    .appName("Bronze Layer Validation") \
    .config("spark.driver.memory", "2g") \
    .config("spark.sql.execution.arrow.pyspark.enabled", "true") \
    .config("spark.serializer", "org.apache.spark.serializer.KryoSerializer") \
    .getOrCreate()

# 定义要检查的Bronze层表
bronze_tables = [
    "bronze_loan_daily",
    "bronze_financials",
    "bronze_attributes",
    "bronze_clickstream"
]

# 检查所有Bronze层表
for table in bronze_tables:
    try:
        # 构建表路径
        table_path = f"datamart/bronze/{table}"
        
        # 尝试读取表
        df = spark.read.parquet(table_path)
        
        # 显示表信息
        print(f"\n============= {table} =============")
        print(f"行数: {df.count()}")
        print(f"列数: {len(df.columns)}")
        print("\n模式:")
        df.printSchema()
        print("\n样本数据:")
        df.show(5, truncate=False)
        
        # 计算空值统计
        null_counts = {col_name: df.filter(df[col_name].isNull()).count() 
                      for col_name in df.columns[:20]}  # 仅检查前5列以避免输出过多
        print("\n前10列的空值数量:")
        for col, count in null_counts.items():
            print(f"{col}: {count} ({count/df.count()*100:.2f}%)")
        
    except Exception as e:
        print(f"无法读取表 {table}: {e}")

print("\nBronze层验证完成!")
# Out:
# ============= bronze_loan_daily =============
# 行数: 137500
# 列数: 13
#
# 模式:
# root
#  |-- loan_id: string (nullable = true)
#  |-- Customer_ID: string (nullable = true)
#  |-- loan_start_date: date (nullable = true)
#  |-- tenure: integer (nullable = true)
#  |-- installment_num: integer (nullable = true)
#  |-- loan_amt: integer (nullable = true)
#  |-- due_amt: integer (nullable = true)
#  |-- paid_amt: integer (nullable = true)
#  |-- overdue_amt: integer (nullable = true)
#  |-- balance: integer (nullable = true)
#  |-- snapshot_date: date (nullable = true)
#  |-- bronze_ingest_timestamp: timestamp (nullable = true)
#  |-- bronze_source_file: string (nullable = true)
#
#
# 样本数据:
# +---------------------+-----------+---------------+------+---------------+--------+-------+--------+-----------+-------+-------------+--------------------------+------------------+
# |loan_id              |Customer_ID|loan_start_date|tenure|installment_num|loan_amt|due_amt|paid_amt|overdue_amt|balance|snapshot_date|bronze_ingest_timestamp   |bronze_source_file|
# +---------------------+-----------+---------------+------+---------------+--------+-------+--------+-----------+-------+-------------+--------------------------+------------------+
# |CUS_0x56ef_2024_04_01|CUS_0x56ef |2024-04-01     |10    |3              |10000   |1000   |0       |1000       |8000   |2024-07-01   |2025-05-18 11:33:35.507517|lms_loan_daily.csv|
# |CUS_0x56ef_2024_04_01|CUS_0x56ef |2024-04-01     |10    |4              |10000   |1000   |0       |2000       |8000   |2024-08-01   |2025-05-18 11:33:35.507517|lms_loan_daily.csv|
# |CUS_0x56ef_2024_04_01|CUS_0x56ef |2024-04-01     |10    |5              |10000   |1000   |0       |3000       |8000   |2024-09-01   |2025-05-18 11:33:35.507517|lms_loan_daily.csv|
# |CUS_0x56ef_2024_04_01|CUS_0x56ef |2024-04-01     |10    |6              |10000   |1000   |0       |4000       |8000   |2024-10-01   |2025-05-18 11:33:35.507517|lms_loan_daily.csv|
# |CUS_0x56ef_2024_04_01|CUS_0x56ef |2024-04-01     |10    |7              |10000   |1000   |0       |5000       |8000   |2024-11-01   |2025-05-18 11:33:35.507517|lms_loan_daily.csv|
# +---------------------+-----------+---------------+------+---------------+--------+-------+--------+-----------+-------+-------------+--------------------------+------------------+
# only showing top 5 rows
#
#
# 前10列的空值数量:
# loan_id: 0 (0.00%)
# Customer_ID: 0 (0.00%)
# loan_start_date: 0 (0.00%)
# tenure: 0 (0.00%)
# installment_num: 0 (0.00%)
# loan_amt: 0 (0.00%)
# due_amt: 0 (0.00%)
# paid_amt: 0 (0.00%)
# overdue_amt: 0 (0.00%)
# balance: 0 (0.00%)
# snapshot_date: 0 (0.00%)
# bronze_ingest_timestamp: 0 (0.00%)
# bronze_source_file: 0 (0.00%)
#
# ============= bronze_financials =============
# 行数: 12500
# 列数: 24
#
# 模式:
# root
#  |-- Customer_ID: string (nullable = true)
#  |-- Annual_Income: string (nullable = true)
#  |-- Monthly_Inhand_Salary: double (nullable = true)
#  |-- Num_Bank_Accounts: integer (nullable = true)
#  |-- Num_Credit_Card: integer (nullable = true)
#  |-- Interest_Rate: integer (nullable = true)
#  |-- Num_of_Loan: string (nullable = true)
#  |-- Type_of_Loan: string (nullable = true)
#  |-- Delay_from_due_date: integer (nullable = true)
#  |-- Num_of_Delayed_Payment: string (nullable = true)
#  |-- Changed_Credit_Limit: string (nullable = true)
#  |-- Num_Credit_Inquiries: double (nullable = true)
#  |-- Credit_Mix: string (nullable = true)
#  |-- Outstanding_Debt: string (nullable = true)
#  |-- Credit_Utilization_Ratio: double (nullable = true)
#  |-- Credit_History_Age: string (nullable = true)
#  |-- Payment_of_Min_Amount: string (nullable = true)
#  |-- Total_EMI_per_month: double (nullable = true)
#  |-- Amount_invested_monthly: string (nullable = true)
#  |-- Payment_Behaviour: string (nullable = true)
#  |-- Monthly_Balance: string (nullable = true)
#  |-- snapshot_date: date (nullable = true)
#  |-- bronze_ingest_timestamp: timestamp (nullable = true)
#  |-- bronze_source_file: string (nullable = true)
#
#
# 样本数据:
# +-----------+------------------+---------------------+-----------------+---------------+-------------+-----------+---------------------------------------------------------------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+----------------------+---------------------+-------------------+-----------------------+--------------------------------+------------------+-------------+--------------------------+-----------------------+
# |Customer_ID|Annual_Income     |Monthly_Inhand_Salary|Num_Bank_Accounts|Num_Credit_Card|Interest_Rate|Num_of_Loan|Type_of_Loan                                                         |Delay_from_due_date|Num_of_Delayed_Payment|Changed_Credit_Limit|Num_Credit_Inquiries|Credit_Mix|Outstanding_Debt|Credit_Utilization_Ratio|Credit_History_Age    |Payment_of_Min_Amount|Total_EMI_per_month|Amount_invested_monthly|Payment_Behaviour               |Monthly_Balance   |snapshot_date|bronze_ingest_timestamp   |bronze_source_file     |
# +-----------+------------------+---------------------+-----------------+---------------+-------------+-----------+---------------------------------------------------------------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+----------------------+---------------------+-------------------+-----------------------+--------------------------------+------------------+-------------+--------------------------+-----------------------+
# |CUS_0x1000 |30625.94          |2706.1616666666664   |6                |5              |27           |2          |Credit-Builder Loan, and Home Equity Loan                            |57                 |26                    |1.63                |11.0                |Bad       |1562.91         |30.07719135017377       |10 Years and 9 Months |Yes                  |42.941090422469365 |77.31427572208112      |High_spent_Medium_value_payments|400.36080052211616|2023-05-01   |2025-05-18 11:33:40.218708|features_financials.csv|
# |CUS_0x1009 |52312.68_         |4250.39              |6                |5              |17           |4          |Not Specified, Home Equity Loan, Credit-Builder Loan, and Payday Loan|5                  |18                    |9.73                |4.0                 |_         |202.68          |40.286996673783         |31 Years and 0 Months |Yes                  |108.36646712525564 |58.66019164829086      |High_spent_Medium_value_payments|508.01234122645366|2025-01-01   |2025-05-18 11:33:40.218708|features_financials.csv|
# |CUS_0x100b |113781.38999999998|9549.7825            |1                |4              |1            |0          |NULL                                                                 |14                 |8                     |8.34                |4.0                 |Good      |1030.2          |28.59294254083936       |15 Years and 10 Months|No                   |0.0                |617.0792665202719      |High_spent_Small_value_payments |597.8989834797281 |2024-03-01   |2025-05-18 11:33:40.218708|features_financials.csv|
# |CUS_0x1011 |58918.47          |5208.8725            |3                |3              |17           |3          |Student Loan, Credit-Builder Loan, and Debt Consolidation Loan       |27                 |13                    |14.42               |7.0                 |Standard  |473.14          |27.82995907548726       |15 Years and 10 Months|Yes                  |123.43493879634316 |383.35084463651407     |Low_spent_Medium_value_payments |294.1014665671429 |2023-11-01   |2025-05-18 11:33:40.218708|features_financials.csv|
# |CUS_0x1013 |98620.98          |7962.415000000001    |3                |3              |6            |3          |Student Loan, Debt Consolidation Loan, and Personal Loan             |12                 |9                     |1.33                |3.0                 |Good      |1233.51         |26.52486357896023       |17 Years and 10 Months|No                   |228.018083652734   |332.3337079767732      |High_spent_Medium_value_payments|485.8897083704929 |2023-12-01   |2025-05-18 11:33:40.218708|features_financials.csv|
# +-----------+------------------+---------------------+-----------------+---------------+-------------+-----------+---------------------------------------------------------------------+-------------------+----------------------+--------------------+--------------------+----------+----------------+------------------------+----------------------+---------------------+-------------------+-----------------------+--------------------------------+------------------+-------------+--------------------------+-----------------------+
# only showing top 5 rows
#
#
# 前10列的空值数量:
# Customer_ID: 0 (0.00%)
# Annual_Income: 0 (0.00%)
# Monthly_Inhand_Salary: 0 (0.00%)
# Num_Bank_Accounts: 0 (0.00%)
# Num_Credit_Card: 0 (0.00%)
# Interest_Rate: 0 (0.00%)
# Num_of_Loan: 0 (0.00%)
# Type_of_Loan: 1426 (11.41%)
# Delay_from_due_date: 0 (0.00%)
# Num_of_Delayed_Payment: 0 (0.00%)
# Changed_Credit_Limit: 0 (0.00%)
# Num_Credit_Inquiries: 0 (0.00%)
# Credit_Mix: 0 (0.00%)
# Outstanding_Debt: 0 (0.00%)
# Credit_Utilization_Ratio: 0 (0.00%)
# Credit_History_Age: 0 (0.00%)
# Payment_of_Min_Amount: 0 (0.00%)
# Total_EMI_per_month: 0 (0.00%)
# Amount_invested_monthly: 0 (0.00%)
# Payment_Behaviour: 0 (0.00%)
#
# ============= bronze_attributes =============
# 行数: 12500
# 列数: 8
#
# 模式:
# root
#  |-- Customer_ID: string (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- Age: string (nullable = true)
#  |-- SSN: string (nullable = true)
#  |-- Occupation: string (nullable = true)
#  |-- snapshot_date: date (nullable = true)
#  |-- bronze_ingest_timestamp: timestamp (nullable = true)
#  |-- bronze_source_file: string (nullable = true)
#
#
# 样本数据:
# +-----------+--------------+---+-----------+-------------+-------------+--------------------------+-----------------------+
# |Customer_ID|Name          |Age|SSN        |Occupation   |snapshot_date|bronze_ingest_timestamp   |bronze_source_file     |
# +-----------+--------------+---+-----------+-------------+-------------+--------------------------+-----------------------+
# |CUS_0x1000 |Alistair Barrf|18 |913-74-1218|Lawyer       |2023-05-01   |2025-05-18 11:33:41.632109|features_attributes.csv|
# |CUS_0x1009 |Arunah        |26 |063-67-6938|Mechanic     |2025-01-01   |2025-05-18 11:33:41.632109|features_attributes.csv|
# |CUS_0x100b |Shirboni      |19 |#F%$D@*&8  |Media_Manager|2024-03-01   |2025-05-18 11:33:41.632109|features_attributes.csv|
# |CUS_0x1011 |Schneyerh     |44 |793-05-8223|Doctor       |2023-11-01   |2025-05-18 11:33:41.632109|features_attributes.csv|
# |CUS_0x1013 |Cameront      |44 |930-49-9615|Mechanic     |2023-12-01   |2025-05-18 11:33:41.632109|features_attributes.csv|
# +-----------+--------------+---+-----------+-------------+-------------+--------------------------+-----------------------+
# only showing top 5 rows
#
#
# 前10列的空值数量:
# Customer_ID: 0 (0.00%)
# Name: 0 (0.00%)
# Age: 0 (0.00%)
# SSN: 0 (0.00%)
# Occupation: 0 (0.00%)
# snapshot_date: 0 (0.00%)
# bronze_ingest_timestamp: 0 (0.00%)
# bronze_source_file: 0 (0.00%)
#
# ============= bronze_clickstream =============
# 行数: 215376
# 列数: 24
#
# 模式:
# root
#  |-- fe_1: integer (nullable = true)
#  |-- fe_2: integer (nullable = true)
#  |-- fe_3: integer (nullable = true)
#  |-- fe_4: integer (nullable = true)
#  |-- fe_5: integer (nullable = true)
#  |-- fe_6: integer (nullable = true)
#  |-- fe_7: integer (nullable = true)
#  |-- fe_8: integer (nullable = true)
#  |-- fe_9: integer (nullable = true)
#  |-- fe_10: integer (nullable = true)
#  |-- fe_11: integer (nullable = true)
#  |-- fe_12: integer (nullable = true)
#  |-- fe_13: integer (nullable = true)
#  |-- fe_14: integer (nullable = true)
#  |-- fe_15: integer (nullable = true)
#  |-- fe_16: integer (nullable = true)
#  |-- fe_17: integer (nullable = true)
#  |-- fe_18: integer (nullable = true)
#  |-- fe_19: integer (nullable = true)
#  |-- fe_20: integer (nullable = true)
#  |-- Customer_ID: string (nullable = true)
#  |-- snapshot_date: date (nullable = true)
#  |-- bronze_ingest_timestamp: timestamp (nullable = true)
#  |-- bronze_source_file: string (nullable = true)
#
#
# 样本数据:
# +----+----+----+----+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----------+-------------+--------------------------+-----------------------+
# |fe_1|fe_2|fe_3|fe_4|fe_5|fe_6|fe_7|fe_8|fe_9|fe_10|fe_11|fe_12|fe_13|fe_14|fe_15|fe_16|fe_17|fe_18|fe_19|fe_20|Customer_ID|snapshot_date|bronze_ingest_timestamp   |bronze_source_file     |
# +----+----+----+----+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----------+-------------+--------------------------+-----------------------+
# |133 |66  |-16 |235 |211 |177 |156 |146 |116 |-82  |62   |154  |-88  |57   |-16  |118  |21   |254  |-130 |176  |CUS_0x7de0 |2023-05-01   |2025-05-18 11:33:42.744716|feature_clickstream.csv|
# |176 |169 |198 |-95 |168 |-86 |24  |14  |268 |205  |128  |207  |6    |5    |67   |249  |101  |-55  |119  |282  |CUS_0x7e0b |2023-05-01   |2025-05-18 11:33:42.744716|feature_clickstream.csv|
# |122 |-32 |212 |297 |257 |202 |74  |-72 |296 |102  |173  |13   |-18  |127  |83   |48   |116  |-11  |97   |96   |CUS_0x7f50 |2023-05-01   |2025-05-18 11:33:42.744716|feature_clickstream.csv|
# |-4  |66  |-2  |-6  |93  |0   |155 |377 |200 |163  |3    |-164 |127  |-53  |24   |-134 |203  |174  |126  |170  |CUS_0x7f9c |2023-05-01   |2025-05-18 11:33:42.744716|feature_clickstream.csv|
# |125 |29  |-103|5   |89  |91  |35  |253 |162 |85   |56   |134  |246  |236  |190  |108  |179  |45   |103  |-100 |CUS_0x8072 |2023-05-01   |2025-05-18 11:33:42.744716|feature_clickstream.csv|
# +----+----+----+----+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----------+-------------+--------------------------+-----------------------+
# only showing top 5 rows
#
#
# 前10列的空值数量:
# fe_1: 0 (0.00%)
# fe_2: 0 (0.00%)
# fe_3: 0 (0.00%)
# fe_4: 0 (0.00%)
# fe_5: 0 (0.00%)
# fe_6: 0 (0.00%)
# fe_7: 0 (0.00%)
# fe_8: 0 (0.00%)
# fe_9: 0 (0.00%)
# fe_10: 0 (0.00%)
# fe_11: 0 (0.00%)
# fe_12: 0 (0.00%)
# fe_13: 0 (0.00%)
# fe_14: 0 (0.00%)
# fe_15: 0 (0.00%)
# fe_16: 0 (0.00%)
# fe_17: 0 (0.00%)
# fe_18: 0 (0.00%)
# fe_19: 0 (0.00%)
# fe_20: 0 (0.00%)
#
# Bronze层验证完成!

# %%
# 定义要检查的Silver层表
silver_tables = [
    "silver_loan",
    "silver_financials",
    "silver_attributes",
    "silver_clickstream_detailed",
    "silver_clickstream_aggregated"
]

# 检查所有Silver层表
for table in silver_tables:
    try:
        # 构建表路径
        table_path = f"datamart/silver/{table}"
        
        # 尝试读取表
        df = spark.read.parquet(table_path)
        
        # 显示表信息
        print(f"\n============= {table} =============")
        print(f"行数: {df.count()}")
        print(f"列数: {len(df.columns)}")
        print("\n模式:")
        df.printSchema()
        print("\n样本数据:")
        df.show(5, truncate=False)
        
    except Exception as e:
        print(f"无法读取表 {table}: {e}")

print("\nSilver层验证完成!")
# Out:
# ============= silver_loan =============
# 行数: 137500
# 列数: 27
#
# 模式:
# root
#  |-- loan_id: string (nullable = true)
#  |-- Customer_ID: string (nullable = true)
#  |-- loan_start_date: date (nullable = true)
#  |-- tenure: integer (nullable = true)
#  |-- installment_num: integer (nullable = true)
#  |-- loan_amt: integer (nullable = true)
#  |-- due_amt: integer (nullable = true)
#  |-- paid_amt: integer (nullable = true)
#  |-- overdue_amt: integer (nullable = true)
#  |-- balance: integer (nullable = true)
#  |-- snapshot_date: date (nullable = true)
#  |-- bronze_ingest_timestamp: timestamp (nullable = true)
#  |-- bronze_source_file: string (nullable = true)
#  |-- payment_made_flag: integer (nullable = true)
#  |-- monthly_overdue_flag: integer (nullable = true)
#  |-- total_due_amount: integer (nullable = true)
#  |-- total_paid_amount: long (nullable = true)
#  |-- payment_ratio: double (nullable = true)
#  |-- payment_status: string (nullable = true)
#  |-- consecutive_missed_payments: long (nullable = true)
#  |-- loan_age_months: double (nullable = true)
#  |-- remaining_tenure: integer (nullable = true)
#  |-- expected_end_date: date (nullable = true)
#  |-- is_active_loan: boolean (nullable = true)
#  |-- is_default: boolean (nullable = true)
#  |-- percent_paid: double (nullable = true)
#  |-- silver_process_timestamp: timestamp (nullable = true)
#
#
# 样本数据:
# +---------------------+-----------+---------------+------+---------------+--------+-------+--------+-----------+-------+-------------+--------------------------+------------------+-----------------+--------------------+----------------+-----------------+-------------+--------------+---------------------------+------------------+----------------+-----------------+--------------+----------+-----------------+--------------------------+
# |loan_id              |Customer_ID|loan_start_date|tenure|installment_num|loan_amt|due_amt|paid_amt|overdue_amt|balance|snapshot_date|bronze_ingest_timestamp   |bronze_source_file|payment_made_flag|monthly_overdue_flag|total_due_amount|total_paid_amount|payment_ratio|payment_status|consecutive_missed_payments|loan_age_months   |remaining_tenure|expected_end_date|is_active_loan|is_default|percent_paid     |silver_process_timestamp  |
# +---------------------+-----------+---------------+------+---------------+--------+-------+--------+-----------+-------+-------------+--------------------------+------------------+-----------------+--------------------+----------------+-----------------+-------------+--------------+---------------------------+------------------+----------------+-----------------+--------------+----------+-----------------+--------------------------+
# |CUS_0x1000_2023_05_01|CUS_0x1000 |2023-05-01     |10    |0              |10000   |0      |0       |0          |10000  |2023-05-01   |2025-05-18 11:33:35.507517|lms_loan_daily.csv|1                |0                   |0               |0                |1.0          |LOAN_INITIATED|0                          |0.0               |10              |2024-02-25       |true          |false     |0.0              |2025-05-18 11:37:36.093022|
# |CUS_0x1000_2023_05_01|CUS_0x1000 |2023-05-01     |10    |1              |10000   |1000   |1000    |0          |9000   |2023-06-01   |2025-05-18 11:33:35.507517|lms_loan_daily.csv|1                |0                   |1000            |1000             |1.0          |PAID_ON_TIME  |0                          |1.0333333333333334|9               |2024-02-25       |true          |false     |100.0            |2025-05-18 11:37:36.093022|
# |CUS_0x1000_2023_05_01|CUS_0x1000 |2023-05-01     |10    |2              |10000   |1000   |1000    |0          |8000   |2023-07-01   |2025-05-18 11:33:35.507517|lms_loan_daily.csv|1                |0                   |2000            |2000             |1.0          |PAID_ON_TIME  |0                          |2.033333333333333 |8               |2024-02-25       |true          |false     |100.0            |2025-05-18 11:37:36.093022|
# |CUS_0x1000_2023_05_01|CUS_0x1000 |2023-05-01     |10    |3              |10000   |1000   |0       |1000       |8000   |2023-08-01   |2025-05-18 11:33:35.507517|lms_loan_daily.csv|0                |1                   |3000            |2000             |0.0          |MISSED_PAYMENT|1                          |3.066666666666667 |7               |2024-02-25       |true          |false     |66.66666666666666|2025-05-18 11:37:36.093022|
# |CUS_0x1000_2023_05_01|CUS_0x1000 |2023-05-01     |10    |4              |10000   |1000   |2000    |0          |6000   |2023-09-01   |2025-05-18 11:33:35.507517|lms_loan_daily.csv|1                |0                   |4000            |4000             |2.0          |PAID_ON_TIME  |0                          |4.1               |6               |2024-02-25       |true          |false     |100.0            |2025-05-18 11:37:36.093022|
# +---------------------+-----------+---------------+------+---------------+--------+-------+--------+-----------+-------+-------------+--------------------------+------------------+-----------------+--------------------+----------------+-----------------+-------------+--------------+---------------------------+------------------+----------------+-----------------+--------------+----------+-----------------+--------------------------+
# only showing top 5 rows
#
#
# ============= silver_financials =============
# 行数: 12500
# 列数: 35
#
# 模式:
# root
#  |-- Customer_ID: string (nullable = true)
#  |-- snapshot_date: date (nullable = true)
#  |-- annual_income: double (nullable = true)
#  |-- Monthly_Inhand_Salary: double (nullable = true)
#  |-- Num_Bank_Accounts: integer (nullable = true)
#  |-- Num_Credit_Card: integer (nullable = true)
#  |-- Interest_Rate: integer (nullable = true)
#  |-- num_of_loans: integer (nullable = true)
#  |-- loan_types_count: integer (nullable = true)
#  |-- has_personal_loan: boolean (nullable = true)
#  |-- has_student_loan: boolean (nullable = true)
#  |-- has_mortgage_loan: boolean (nullable = true)
#  |-- has_auto_loan: boolean (nullable = true)
#  |-- has_home_equity_loan: boolean (nullable = true)
#  |-- has_debt_consolidation_loan: boolean (nullable = true)
#  |-- has_credit_builder_loan: boolean (nullable = true)
#  |-- has_payday_loan: boolean (nullable = true)
#  |-- Delay_from_due_date: integer (nullable = true)
#  |-- num_delayed_payments: integer (nullable = true)
#  |-- changed_credit_limit: double (nullable = true)
#  |-- Num_Credit_Inquiries: double (nullable = true)
#  |-- credit_mix: string (nullable = true)
#  |-- outstanding_debt: double (nullable = true)
#  |-- Credit_Utilization_Ratio: double (nullable = true)
#  |-- credit_history_years: integer (nullable = true)
#  |-- credit_history_months: integer (nullable = true)
#  |-- credit_history_total_months: integer (nullable = true)
#  |-- is_min_payment_made: boolean (nullable = true)
#  |-- Total_EMI_per_month: double (nullable = true)
#  |-- amount_invested_monthly: double (nullable = true)
#  |-- payment_behavior_spent_level: string (nullable = true)
#  |-- payment_behavior_value_level: string (nullable = true)
#  |-- monthly_balance: double (nullable = true)
#  |-- bronze_ingest_timestamp: timestamp (nullable = true)
#  |-- silver_process_timestamp: timestamp (nullable = true)
#
#
# 样本数据:
# +-----------+-------------+------------------+---------------------+-----------------+---------------+-------------+------------+----------------+-----------------+----------------+-----------------+-------------+--------------------+---------------------------+-----------------------+---------------+-------------------+--------------------+--------------------+--------------------+----------+----------------+------------------------+--------------------+---------------------+---------------------------+-------------------+-------------------+-----------------------+----------------------------+----------------------------+------------------+--------------------------+--------------------------+
# |Customer_ID|snapshot_date|annual_income     |Monthly_Inhand_Salary|Num_Bank_Accounts|Num_Credit_Card|Interest_Rate|num_of_loans|loan_types_count|has_personal_loan|has_student_loan|has_mortgage_loan|has_auto_loan|has_home_equity_loan|has_debt_consolidation_loan|has_credit_builder_loan|has_payday_loan|Delay_from_due_date|num_delayed_payments|changed_credit_limit|Num_Credit_Inquiries|credit_mix|outstanding_debt|Credit_Utilization_Ratio|credit_history_years|credit_history_months|credit_history_total_months|is_min_payment_made|Total_EMI_per_month|amount_invested_monthly|payment_behavior_spent_level|payment_behavior_value_level|monthly_balance   |bronze_ingest_timestamp   |silver_process_timestamp  |
# +-----------+-------------+------------------+---------------------+-----------------+---------------+-------------+------------+----------------+-----------------+----------------+-----------------+-------------+--------------------+---------------------------+-----------------------+---------------+-------------------+--------------------+--------------------+--------------------+----------+----------------+------------------------+--------------------+---------------------+---------------------------+-------------------+-------------------+-----------------------+----------------------------+----------------------------+------------------+--------------------------+--------------------------+
# |CUS_0x1000 |2023-05-01   |30625.94          |2706.1616666666664   |6                |5              |27           |2           |2               |false            |false           |false            |false        |false               |false                      |true                   |false          |57                 |26                  |1.63                |11.0                |BAD       |1562.91         |30.07719135017377       |10                  |9                    |129                        |true               |42.941090422469365 |77.31427572208112      |HIGH                        |MEDIUM                      |400.36080052211616|2025-05-18 11:33:40.218708|2025-05-18 11:37:46.026054|
# |CUS_0x1009 |2025-01-01   |52312.68          |4250.39              |6                |5              |17           |4           |4               |false            |false           |false            |false        |true                |false                      |true                   |false          |5                  |18                  |9.73                |4.0                 |UNKNOWN   |202.68          |40.286996673783         |31                  |0                    |372                        |true               |108.36646712525564 |58.66019164829086      |HIGH                        |MEDIUM                      |508.01234122645366|2025-05-18 11:33:40.218708|2025-05-18 11:37:46.026054|
# |CUS_0x100b |2024-03-01   |113781.38999999998|9549.7825            |1                |4              |1            |0           |1               |false            |false           |false            |false        |false               |false                      |false                  |false          |14                 |8                   |8.34                |4.0                 |GOOD      |1030.2          |28.59294254083936       |15                  |10                   |190                        |false              |0.0                |617.0792665202719      |HIGH                        |SMALL                       |597.8989834797281 |2025-05-18 11:33:40.218708|2025-05-18 11:37:46.026054|
# |CUS_0x1011 |2023-11-01   |58918.47          |5208.8725            |3                |3              |17           |3           |3               |false            |true            |false            |false        |false               |false                      |true                   |false          |27                 |13                  |14.42               |7.0                 |STANDARD  |473.14          |27.82995907548726       |15                  |10                   |190                        |true               |123.43493879634316 |383.35084463651407     |LOW                         |MEDIUM                      |294.1014665671429 |2025-05-18 11:33:40.218708|2025-05-18 11:37:46.026054|
# |CUS_0x1013 |2023-12-01   |98620.98          |7962.415000000001    |3                |3              |6            |3           |3               |false            |true            |false            |false        |false               |true                       |false                  |false          |12                 |9                   |1.33                |3.0                 |GOOD      |1233.51         |26.52486357896023       |17                  |10                   |214                        |false              |228.018083652734   |332.3337079767732      |HIGH                        |MEDIUM                      |485.8897083704929 |2025-05-18 11:33:40.218708|2025-05-18 11:37:46.026054|
# +-----------+-------------+------------------+---------------------+-----------------+---------------+-------------+------------+----------------+-----------------+----------------+-----------------+-------------+--------------------+---------------------------+-----------------------+---------------+-------------------+--------------------+--------------------+--------------------+----------+----------------+------------------------+--------------------+---------------------+---------------------------+-------------------+-------------------+-----------------------+----------------------------+----------------------------+------------------+--------------------------+--------------------------+
# only showing top 5 rows
#
#
# ============= silver_attributes =============
# 行数: 12500
# 列数: 11
#
# 模式:
# root
#  |-- Customer_ID: string (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- snapshot_date: date (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- is_valid_age: boolean (nullable = true)
#  |-- SSN: string (nullable = true)
#  |-- is_valid_ssn: boolean (nullable = true)
#  |-- occupation: string (nullable = true)
#  |-- data_age_months: double (nullable = true)
#  |-- bronze_ingest_timestamp: timestamp (nullable = true)
#  |-- silver_process_timestamp: timestamp (nullable = true)
#
#
# 样本数据:
# +-----------+--------------+-------------+---+------------+-----------+------------+-------------+---------------+--------------------------+--------------------------+
# |Customer_ID|Name          |snapshot_date|age|is_valid_age|SSN        |is_valid_ssn|occupation   |data_age_months|bronze_ingest_timestamp   |silver_process_timestamp  |
# +-----------+--------------+-------------+---+------------+-----------+------------+-------------+---------------+--------------------------+--------------------------+
# |CUS_0x1000 |Alistair Barrf|2023-05-01   |18 |true        |913-74-1218|true        |Lawyer       |24.0           |2025-05-18 11:33:41.632109|2025-05-18 11:37:44.578241|
# |CUS_0x1009 |Arunah        |2025-01-01   |26 |true        |063-67-6938|true        |Mechanic     |4.0            |2025-05-18 11:33:41.632109|2025-05-18 11:37:44.578241|
# |CUS_0x100b |Shirboni      |2024-03-01   |19 |true        |#F%$D@*&8  |false       |Media_manager|14.0           |2025-05-18 11:33:41.632109|2025-05-18 11:37:44.578241|
# |CUS_0x1011 |Schneyerh     |2023-11-01   |44 |true        |793-05-8223|true        |Doctor       |18.0           |2025-05-18 11:33:41.632109|2025-05-18 11:37:44.578241|
# |CUS_0x1013 |Cameront      |2023-12-01   |44 |true        |930-49-9615|true        |Mechanic     |17.0           |2025-05-18 11:33:41.632109|2025-05-18 11:37:44.578241|
# +-----------+--------------+-------------+---+------------+-----------+------------+-------------+---------------+--------------------------+--------------------------+
# only showing top 5 rows
#
#
# ============= silver_clickstream_detailed =============
# 行数: 215376
# 列数: 71
#
# 模式:
# root
#  |-- Customer_ID: string (nullable = true)
#  |-- snapshot_date: date (nullable = true)
#  |-- fe_1: integer (nullable = true)
#  |-- fe_2: integer (nullable = true)
#  |-- fe_3: integer (nullable = true)
#  |-- fe_4: integer (nullable = true)
#  |-- fe_5: integer (nullable = true)
#  |-- fe_6: integer (nullable = true)
#  |-- fe_7: integer (nullable = true)
#  |-- fe_8: integer (nullable = true)
#  |-- fe_9: integer (nullable = true)
#  |-- fe_10: integer (nullable = true)
#  |-- fe_11: integer (nullable = true)
#  |-- fe_12: integer (nullable = true)
#  |-- fe_13: integer (nullable = true)
#  |-- fe_14: integer (nullable = true)
#  |-- fe_15: integer (nullable = true)
#  |-- fe_16: integer (nullable = true)
#  |-- fe_17: integer (nullable = true)
#  |-- fe_18: integer (nullable = true)
#  |-- fe_19: integer (nullable = true)
#  |-- fe_20: integer (nullable = true)
#  |-- fe_1_normalized: double (nullable = true)
#  |-- fe_2_normalized: double (nullable = true)
#  |-- fe_3_normalized: double (nullable = true)
#  |-- fe_4_normalized: double (nullable = true)
#  |-- fe_5_normalized: double (nullable = true)
#  |-- fe_6_normalized: double (nullable = true)
#  |-- fe_7_normalized: double (nullable = true)
#  |-- fe_8_normalized: double (nullable = true)
#  |-- fe_9_normalized: double (nullable = true)
#  |-- fe_10_normalized: double (nullable = true)
#  |-- fe_11_normalized: double (nullable = true)
#  |-- fe_12_normalized: double (nullable = true)
#  |-- fe_13_normalized: double (nullable = true)
#  |-- fe_14_normalized: double (nullable = true)
#  |-- fe_15_normalized: double (nullable = true)
#  |-- fe_16_normalized: double (nullable = true)
#  |-- fe_17_normalized: double (nullable = true)
#  |-- fe_18_normalized: double (nullable = true)
#  |-- fe_19_normalized: double (nullable = true)
#  |-- fe_20_normalized: double (nullable = true)
#  |-- fe_1_is_outlier: boolean (nullable = true)
#  |-- fe_2_is_outlier: boolean (nullable = true)
#  |-- fe_3_is_outlier: boolean (nullable = true)
#  |-- fe_4_is_outlier: boolean (nullable = true)
#  |-- fe_5_is_outlier: boolean (nullable = true)
#  |-- fe_6_is_outlier: boolean (nullable = true)
#  |-- fe_7_is_outlier: boolean (nullable = true)
#  |-- fe_8_is_outlier: boolean (nullable = true)
#  |-- fe_9_is_outlier: boolean (nullable = true)
#  |-- fe_10_is_outlier: boolean (nullable = true)
#  |-- fe_11_is_outlier: boolean (nullable = true)
#  |-- fe_12_is_outlier: boolean (nullable = true)
#  |-- fe_13_is_outlier: boolean (nullable = true)
#  |-- fe_14_is_outlier: boolean (nullable = true)
#  |-- fe_15_is_outlier: boolean (nullable = true)
#  |-- fe_16_is_outlier: boolean (nullable = true)
#  |-- fe_17_is_outlier: boolean (nullable = true)
#  |-- fe_18_is_outlier: boolean (nullable = true)
#  |-- fe_19_is_outlier: boolean (nullable = true)
#  |-- fe_20_is_outlier: boolean (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- quarter: integer (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- row_num_by_customer: integer (nullable = true)
#  |-- months_since_first: integer (nullable = true)
#  |-- first_snapshot_date: date (nullable = true)
#  |-- bronze_ingest_timestamp: timestamp (nullable = true)
#  |-- bronze_source_file: string (nullable = true)
#  |-- silver_process_timestamp: timestamp (nullable = true)
#
#
# 样本数据:
# +-----------+-------------+----+----+----+----+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-------------------+--------------------+-------------------+--------------------+-------------------+--------------------+-------------------+--------------------+--------------------+-------------------+-------------------+--------------------+--------------------+--------------------+-------------------+-------------------+-------------------+-------------------+--------------------+-------------------+---------------+---------------+---------------+---------------+---------------+---------------+---------------+---------------+---------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+-----+-------+----+-------------------+------------------+-------------------+--------------------------+-----------------------+--------------------------+
# |Customer_ID|snapshot_date|fe_1|fe_2|fe_3|fe_4|fe_5|fe_6|fe_7|fe_8|fe_9|fe_10|fe_11|fe_12|fe_13|fe_14|fe_15|fe_16|fe_17|fe_18|fe_19|fe_20|fe_1_normalized    |fe_2_normalized     |fe_3_normalized    |fe_4_normalized     |fe_5_normalized    |fe_6_normalized     |fe_7_normalized    |fe_8_normalized     |fe_9_normalized     |fe_10_normalized   |fe_11_normalized   |fe_12_normalized    |fe_13_normalized    |fe_14_normalized    |fe_15_normalized   |fe_16_normalized   |fe_17_normalized   |fe_18_normalized   |fe_19_normalized    |fe_20_normalized   |fe_1_is_outlier|fe_2_is_outlier|fe_3_is_outlier|fe_4_is_outlier|fe_5_is_outlier|fe_6_is_outlier|fe_7_is_outlier|fe_8_is_outlier|fe_9_is_outlier|fe_10_is_outlier|fe_11_is_outlier|fe_12_is_outlier|fe_13_is_outlier|fe_14_is_outlier|fe_15_is_outlier|fe_16_is_outlier|fe_17_is_outlier|fe_18_is_outlier|fe_19_is_outlier|fe_20_is_outlier|month|quarter|year|row_num_by_customer|months_since_first|first_snapshot_date|bronze_ingest_timestamp   |bronze_source_file     |silver_process_timestamp  |
# +-----------+-------------+----+----+----+----+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-------------------+--------------------+-------------------+--------------------+-------------------+--------------------+-------------------+--------------------+--------------------+-------------------+-------------------+--------------------+--------------------+--------------------+-------------------+-------------------+-------------------+-------------------+--------------------+-------------------+---------------+---------------+---------------+---------------+---------------+---------------+---------------+---------------+---------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+-----+-------+----+-------------------+------------------+-------------------+--------------------------+-----------------------+--------------------------+
# |CUS_0x106f |2023-01-01   |68  |60  |110 |95  |-16 |178 |199 |95  |140 |-55  |203  |53   |53   |275  |260  |105  |134  |-99  |105  |196  |-0.3347049245201281|-0.43126382150876796|0.05632503137543624|-0.10613894910902176|-1.2214943893940038|0.7456247009304136  |0.9163344354733695 |-0.15680511399161604|0.2554609440772026  |-1.7139149150992725|1.0303884131076548 |-0.46548497312499987|-0.47006289707334387|1.7312116027681639  |1.5858241176005323 |0.05100814105770604|0.33436427207383734|-1.9477848848654093|0.045378236456755525|0.9262895661493246 |false          |false          |false          |false          |false          |false          |false          |false          |false          |false           |false           |false           |false           |false           |false           |false           |false           |false           |false           |false           |1    |1      |2023|1                  |0                 |2023-01-01         |2025-05-18 11:33:42.744716|feature_clickstream.csv|2025-05-18 11:37:51.668067|
# |CUS_0x106f |2023-02-01   |210 |263 |132 |-92 |68  |200 |199 |113 |82  |306  |179  |318  |163  |31   |38   |7    |30   |145  |-58  |237  |1.087661980369442  |1.6001581324689365  |0.2750131965378081 |-1.9700613547953343 |-0.3872805521162047|0.9650314524586311  |0.9163344354733695 |0.022757296332799798|-0.32346145829103834|1.8671612309993253 |0.7911907492471406 |2.1689409562330213  |0.6203218019028383  |-0.6829479386338178 |-0.6090249710993327|-0.9216784578561149|-0.6923051632907679|0.4389529906166849 |-1.5422819814648354 |1.3220831190872666 |false          |false          |false          |false          |false          |false          |false          |false          |false          |false           |false           |false           |false           |false           |false           |false           |false           |false           |false           |false           |2    |1      |2023|2                  |1                 |2023-01-01         |2025-05-18 11:33:42.744716|feature_clickstream.csv|2025-05-18 11:37:51.668067|
# |CUS_0x106f |2023-03-01   |200 |192 |45  |156 |213 |62  |225 |177 |267 |226  |59   |319  |90   |189  |59   |-16  |-58  |53   |-28  |175  |0.9874952969265145 |0.8896607988117099  |-0.5897990929679351|0.5018785201255507  |1.0527314288990437 |-0.4112472616729156 |1.1754966543164613 |0.6612014219307227  |1.5231013768490405  |1.0735709493154255 |-0.4047975700554301|2.1788821861551266  |-0.10329713469044625|0.880319305388777   |-0.4014041113574536|-1.1499620473971137|-1.5610254547531262|-0.4609645689913179|-1.250074579393377  |0.7235660390347688 |false          |false          |false          |false          |false          |false          |false          |false          |false          |false           |false           |false           |false           |false           |false           |false           |false           |false           |false           |false           |3    |1      |2023|3                  |2                 |2023-01-01         |2025-05-18 11:33:42.744716|feature_clickstream.csv|2025-05-18 11:37:51.668067|
# |CUS_0x106f |2023-04-01   |161 |158 |-93 |-7  |220 |242 |59  |118 |12  |96   |-169 |38   |168  |16   |32   |167  |12   |116  |179  |254  |0.5968452314990974 |0.5494226390321929  |-1.9615703108046312|-1.122823897665192  |1.1222492486721936 |1.3838988871943192  |-0.4791544352202021|0.07263574364513753 |-1.0221609094251223 |-0.2160132584209118|-2.6771753767303146|-0.614603421956586  |0.669884742765392   |-0.8313593858511527 |-0.6683452167398696|0.6663812954725724 |-0.8699979501807957|0.15528332508807535|0.7661564948996863  |1.486192641037145  |false          |false          |false          |false          |false          |false          |false          |false          |false          |false           |false           |false           |false           |false           |false           |false           |false           |false           |false           |false           |4    |2      |2023|4                  |3                 |2023-01-01         |2025-05-18 11:33:42.744716|feature_clickstream.csv|2025-05-18 11:37:51.668067|
# |CUS_0x106f |2023-05-01   |-57 |148 |118 |135 |-138|69  |244 |66  |99  |259  |6    |27   |62   |95   |172  |140  |-69  |116  |33   |-31  |-1.5867884675567216|0.4493525920382173  |0.13584800052538964|0.2925610307169274  |-2.4330906768689027|-0.34143602255030087|1.3648844296248748 |-0.4461001084031748 |-0.1537773058727608 |1.4009269405100342 |-0.9330257444140655|-0.7239569510997491 |-0.38084960352074715|-0.04972576383985534|0.7157938482059913 |0.3983962120983564 |-1.669615491185921 |0.15528332508807535|-0.6559195285147447 |-1.2650552269461117|false          |false          |false          |false          |false          |false          |false          |false          |false          |false           |false           |false           |false           |false           |false           |false           |false           |false           |false           |false           |5    |2      |2023|5                  |4                 |2023-01-01         |2025-05-18 11:33:42.744716|feature_clickstream.csv|2025-05-18 11:37:51.668067|
# +-----------+-------------+----+----+----+----+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-------------------+--------------------+-------------------+--------------------+-------------------+--------------------+-------------------+--------------------+--------------------+-------------------+-------------------+--------------------+--------------------+--------------------+-------------------+-------------------+-------------------+-------------------+--------------------+-------------------+---------------+---------------+---------------+---------------+---------------+---------------+---------------+---------------+---------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+-----+-------+----+-------------------+------------------+-------------------+--------------------------+-----------------------+--------------------------+
# only showing top 5 rows
#
#
# ============= silver_clickstream_aggregated =============
# 行数: 8974
# 列数: 106
#
# 模式:
# root
#  |-- Customer_ID: string (nullable = true)
#  |-- fe_1_mean: double (nullable = true)
#  |-- fe_1_max: integer (nullable = true)
#  |-- fe_1_min: integer (nullable = true)
#  |-- fe_1_stddev: double (nullable = true)
#  |-- fe_1_outlier_count: long (nullable = true)
#  |-- fe_2_mean: double (nullable = true)
#  |-- fe_2_max: integer (nullable = true)
#  |-- fe_2_min: integer (nullable = true)
#  |-- fe_2_stddev: double (nullable = true)
#  |-- fe_2_outlier_count: long (nullable = true)
#  |-- fe_3_mean: double (nullable = true)
#  |-- fe_3_max: integer (nullable = true)
#  |-- fe_3_min: integer (nullable = true)
#  |-- fe_3_stddev: double (nullable = true)
#  |-- fe_3_outlier_count: long (nullable = true)
#  |-- fe_4_mean: double (nullable = true)
#  |-- fe_4_max: integer (nullable = true)
#  |-- fe_4_min: integer (nullable = true)
#  |-- fe_4_stddev: double (nullable = true)
#  |-- fe_4_outlier_count: long (nullable = true)
#  |-- fe_5_mean: double (nullable = true)
#  |-- fe_5_max: integer (nullable = true)
#  |-- fe_5_min: integer (nullable = true)
#  |-- fe_5_stddev: double (nullable = true)
#  |-- fe_5_outlier_count: long (nullable = true)
#  |-- fe_6_mean: double (nullable = true)
#  |-- fe_6_max: integer (nullable = true)
#  |-- fe_6_min: integer (nullable = true)
#  |-- fe_6_stddev: double (nullable = true)
#  |-- fe_6_outlier_count: long (nullable = true)
#  |-- fe_7_mean: double (nullable = true)
#  |-- fe_7_max: integer (nullable = true)
#  |-- fe_7_min: integer (nullable = true)
#  |-- fe_7_stddev: double (nullable = true)
#  |-- fe_7_outlier_count: long (nullable = true)
#  |-- fe_8_mean: double (nullable = true)
#  |-- fe_8_max: integer (nullable = true)
#  |-- fe_8_min: integer (nullable = true)
#  |-- fe_8_stddev: double (nullable = true)
#  |-- fe_8_outlier_count: long (nullable = true)
#  |-- fe_9_mean: double (nullable = true)
#  |-- fe_9_max: integer (nullable = true)
#  |-- fe_9_min: integer (nullable = true)
#  |-- fe_9_stddev: double (nullable = true)
#  |-- fe_9_outlier_count: long (nullable = true)
#  |-- fe_10_mean: double (nullable = true)
#  |-- fe_10_max: integer (nullable = true)
#  |-- fe_10_min: integer (nullable = true)
#  |-- fe_10_stddev: double (nullable = true)
#  |-- fe_10_outlier_count: long (nullable = true)
#  |-- fe_11_mean: double (nullable = true)
#  |-- fe_11_max: integer (nullable = true)
#  |-- fe_11_min: integer (nullable = true)
#  |-- fe_11_stddev: double (nullable = true)
#  |-- fe_11_outlier_count: long (nullable = true)
#  |-- fe_12_mean: double (nullable = true)
#  |-- fe_12_max: integer (nullable = true)
#  |-- fe_12_min: integer (nullable = true)
#  |-- fe_12_stddev: double (nullable = true)
#  |-- fe_12_outlier_count: long (nullable = true)
#  |-- fe_13_mean: double (nullable = true)
#  |-- fe_13_max: integer (nullable = true)
#  |-- fe_13_min: integer (nullable = true)
#  |-- fe_13_stddev: double (nullable = true)
#  |-- fe_13_outlier_count: long (nullable = true)
#  |-- fe_14_mean: double (nullable = true)
#  |-- fe_14_max: integer (nullable = true)
#  |-- fe_14_min: integer (nullable = true)
#  |-- fe_14_stddev: double (nullable = true)
#  |-- fe_14_outlier_count: long (nullable = true)
#  |-- fe_15_mean: double (nullable = true)
#  |-- fe_15_max: integer (nullable = true)
#  |-- fe_15_min: integer (nullable = true)
#  |-- fe_15_stddev: double (nullable = true)
#  |-- fe_15_outlier_count: long (nullable = true)
#  |-- fe_16_mean: double (nullable = true)
#  |-- fe_16_max: integer (nullable = true)
#  |-- fe_16_min: integer (nullable = true)
#  |-- fe_16_stddev: double (nullable = true)
#  |-- fe_16_outlier_count: long (nullable = true)
#  |-- fe_17_mean: double (nullable = true)
#  |-- fe_17_max: integer (nullable = true)
#  |-- fe_17_min: integer (nullable = true)
#  |-- fe_17_stddev: double (nullable = true)
#  |-- fe_17_outlier_count: long (nullable = true)
#  |-- fe_18_mean: double (nullable = true)
#  |-- fe_18_max: integer (nullable = true)
#  |-- fe_18_min: integer (nullable = true)
#  |-- fe_18_stddev: double (nullable = true)
#  |-- fe_18_outlier_count: long (nullable = true)
#  |-- fe_19_mean: double (nullable = true)
#  |-- fe_19_max: integer (nullable = true)
#  |-- fe_19_min: integer (nullable = true)
#  |-- fe_19_stddev: double (nullable = true)
#  |-- fe_19_outlier_count: long (nullable = true)
#  |-- fe_20_mean: double (nullable = true)
#  |-- fe_20_max: integer (nullable = true)
#  |-- fe_20_min: integer (nullable = true)
#  |-- fe_20_stddev: double (nullable = true)
#  |-- fe_20_outlier_count: long (nullable = true)
#  |-- latest_snapshot_date: date (nullable = true)
#  |-- record_count: long (nullable = true)
#  |-- max_months: integer (nullable = true)
#  |-- first_snapshot_date: date (nullable = true)
#  |-- silver_process_timestamp: timestamp (nullable = true)
#
#
# 样本数据:
# +-----------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+---------+---------+------------------+-------------------+-----------------+---------+---------+------------------+-------------------+------------------+---------+---------+------------------+-------------------+------------------+---------+---------+------------------+-------------------+------------------+---------+---------+-----------------+-------------------+------------------+---------+---------+------------------+-------------------+-----------------+---------+---------+------------------+-------------------+------------------+---------+---------+------------------+-------------------+------------------+---------+---------+------------------+-------------------+------------------+---------+---------+------------------+-------------------+------------------+---------+---------+------------------+-------------------+--------------------+------------+----------+-------------------+--------------------------+
# |Customer_ID|fe_1_mean         |fe_1_max|fe_1_min|fe_1_stddev       |fe_1_outlier_count|fe_2_mean         |fe_2_max|fe_2_min|fe_2_stddev       |fe_2_outlier_count|fe_3_mean         |fe_3_max|fe_3_min|fe_3_stddev       |fe_3_outlier_count|fe_4_mean         |fe_4_max|fe_4_min|fe_4_stddev       |fe_4_outlier_count|fe_5_mean         |fe_5_max|fe_5_min|fe_5_stddev       |fe_5_outlier_count|fe_6_mean         |fe_6_max|fe_6_min|fe_6_stddev       |fe_6_outlier_count|fe_7_mean         |fe_7_max|fe_7_min|fe_7_stddev       |fe_7_outlier_count|fe_8_mean         |fe_8_max|fe_8_min|fe_8_stddev       |fe_8_outlier_count|fe_9_mean         |fe_9_max|fe_9_min|fe_9_stddev       |fe_9_outlier_count|fe_10_mean        |fe_10_max|fe_10_min|fe_10_stddev      |fe_10_outlier_count|fe_11_mean       |fe_11_max|fe_11_min|fe_11_stddev      |fe_11_outlier_count|fe_12_mean        |fe_12_max|fe_12_min|fe_12_stddev      |fe_12_outlier_count|fe_13_mean        |fe_13_max|fe_13_min|fe_13_stddev      |fe_13_outlier_count|fe_14_mean        |fe_14_max|fe_14_min|fe_14_stddev     |fe_14_outlier_count|fe_15_mean        |fe_15_max|fe_15_min|fe_15_stddev      |fe_15_outlier_count|fe_16_mean       |fe_16_max|fe_16_min|fe_16_stddev      |fe_16_outlier_count|fe_17_mean        |fe_17_max|fe_17_min|fe_17_stddev      |fe_17_outlier_count|fe_18_mean        |fe_18_max|fe_18_min|fe_18_stddev      |fe_18_outlier_count|fe_19_mean        |fe_19_max|fe_19_min|fe_19_stddev      |fe_19_outlier_count|fe_20_mean        |fe_20_max|fe_20_min|fe_20_stddev      |fe_20_outlier_count|latest_snapshot_date|record_count|max_months|first_snapshot_date|silver_process_timestamp  |
# +-----------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+---------+---------+------------------+-------------------+-----------------+---------+---------+------------------+-------------------+------------------+---------+---------+------------------+-------------------+------------------+---------+---------+------------------+-------------------+------------------+---------+---------+-----------------+-------------------+------------------+---------+---------+------------------+-------------------+-----------------+---------+---------+------------------+-------------------+------------------+---------+---------+------------------+-------------------+------------------+---------+---------+------------------+-------------------+------------------+---------+---------+------------------+-------------------+------------------+---------+---------+------------------+-------------------+--------------------+------------+----------+-------------------+--------------------------+
# |CUS_0xc39e |87.58333333333333 |321     |-209    |113.33325873825338|1                 |119.04166666666667|265     |-66     |98.9068420575498  |0                 |117.70833333333333|298     |-77     |83.54300073024964 |0                 |113.54166666666667|295     |-94     |110.24320117720232|0                 |130.08333333333334|359     |-32     |94.46596657304529 |0                 |98.125            |247     |-41     |75.05552292629191 |0                 |90.83333333333333 |311     |-73     |98.50873572680118 |0                 |121.70833333333333|317     |-86     |98.86990977021783 |0                 |119.70833333333333|388     |-83     |116.03765474552034|0                 |153.70833333333334|437      |-98      |125.02329493083407|1                  |98.875           |262      |-74      |94.4062969988945  |0                  |98.83333333333333 |259      |-66      |91.34105542305224 |0                  |87.25             |250      |-111     |110.45803846198595|0                  |136.41666666666666|384      |-14      |93.83144771189532|0                  |100.41666666666667|242      |-74      |88.84374004355928 |0                  |85.54166666666667|194      |-140     |90.91418752182535 |0                  |75.66666666666667 |236      |-92      |89.12261542229417 |0                  |116.04166666666667|267      |-231     |113.92311639555584|1                  |74.0              |271      |-200     |114.21261637459511|0                  |110.125           |280      |-40      |96.62806888090114 |0                  |2024-12-01          |24          |23        |2023-01-01         |2025-05-18 11:38:06.073492|
# |CUS_0x1330 |91.70833333333333 |319     |-157    |101.71335646835163|0                 |70.66666666666667 |231     |-230    |117.00972336655975|1                 |101.04166666666667|285     |-76     |101.28070298483047|0                 |110.83333333333333|364     |-104    |108.45823346245828|0                 |114.25            |436     |-96     |129.792225264576  |1                 |128.04166666666666|383     |-78     |115.50135672708394|0                 |112.16666666666667|256     |-86     |97.9710102049566  |0                 |117.66666666666667|287     |-61     |102.24381204478478|0                 |98.41666666666667 |259     |-37     |93.8629512810481  |0                 |103.79166666666667|289      |-184     |117.61025508623504|0                  |98.79166666666667|332      |-114     |114.3545132915397 |0                  |123.375           |302      |-100     |108.30063330337937|0                  |108.625           |309      |-137     |118.66203836032012|0                  |79.95833333333333 |288      |-126     |96.1608612268217 |0                  |81.58333333333333 |263      |-64      |95.05006308653154 |0                  |97.16666666666667|299      |-178     |120.10888779576734|0                  |139.125           |355      |-48      |98.78316724237376 |0                  |111.08333333333333|282      |-54      |103.98449577854788|0                  |108.58333333333333|308      |-159     |101.42802831336235|0                  |105.91666666666667|204      |-30      |71.94920712417269 |0                  |2024-12-01          |24          |23        |2023-01-01         |2025-05-18 11:38:06.073492|
# |CUS_0x8d04 |111.29166666666667|333     |-94     |102.29347344843133|0                 |69.08333333333333 |264     |-110    |88.61588662490965 |0                 |70.16666666666667 |252     |-177    |109.19733499959828|0                 |70.08333333333333 |297     |-175    |131.23656591013062|0                 |99.33333333333333 |356     |-211    |118.29023505828758|1                 |160.125           |384     |11      |111.70898235652508|0                 |101.04166666666667|281     |-76     |99.66922649516714 |0                 |121.66666666666667|322     |-91     |111.1503747051779 |0                 |115.79166666666667|255     |-82     |76.5540327320268  |0                 |111.20833333333333|380      |-87      |109.59489799560318|0                  |77.375           |323      |-127     |126.80001800164457|0                  |120.20833333333333|335      |-19      |92.35234003610805 |0                  |130.79166666666666|355      |-59      |131.78044295314663|0                  |77.45833333333333 |308      |-55      |83.71119044546614|0                  |83.70833333333333 |317      |-152     |106.54677648671566|0                  |72.75            |267      |-236     |114.76147285641602|1                  |81.875            |268      |-113     |92.28703451260331 |0                  |99.58333333333333 |236      |-44      |70.32837059213676 |0                  |135.79166666666666|360      |-98      |120.80886059019616|0                  |91.04166666666667 |265      |-125     |108.58155787307956|0                  |2024-12-01          |24          |23        |2023-01-01         |2025-05-18 11:38:06.073492|
# |CUS_0x752f |97.0              |275     |-92     |105.10160715273081|0                 |99.66666666666667 |286     |-134    |111.84875916851395|0                 |90.0              |232     |-132    |90.27927683630921 |0                 |142.95833333333334|413     |-79     |116.27234863874992|1                 |122.04166666666667|272     |-90     |91.3799898020999  |0                 |58.5              |166     |-103    |75.80294820468224 |0                 |108.58333333333333|281     |-117    |101.13568873662692|0                 |83.91666666666667 |360     |-90     |98.12410804542452 |0                 |92.125            |369     |-87     |109.35435519447775|0                 |91.875            |243      |-109     |88.87720522550005 |0                  |77.70833333333333|272      |-132     |112.76619874638918|0                  |118.20833333333333|358      |-99      |106.98068869484432|0                  |78.83333333333333 |333      |-133     |107.063437784077  |0                  |112.29166666666667|328      |-53      |99.79913703846937|0                  |86.70833333333333 |315      |-68      |104.0708283758738 |0                  |73.375           |313      |-115     |97.13182995961904 |0                  |84.58333333333333 |296      |-125     |108.43387753419799|0                  |100.91666666666667|261      |4        |75.43031144081252 |0                  |110.125           |290      |-82      |103.3837563979783 |0                  |61.0              |184      |-165     |103.12128781197411|0                  |2024-12-01          |24          |23        |2023-01-01         |2025-05-18 11:38:06.073492|
# |CUS_0x9a71 |124.08333333333333|318     |-96     |100.19065159318342|0                 |111.375           |318     |-31     |97.02971866571514 |0                 |116.625           |324     |-117    |110.30385404595481|0                 |112.625           |302     |-125    |97.01403417076807 |0                 |81.08333333333333 |283     |-132    |105.01632033275534|0                 |86.91666666666667 |265     |-177    |105.0448834367095 |0                 |104.29166666666667|235     |-131    |90.02969518160523 |0                 |108.45833333333333|311     |-85     |109.92407623551759|0                 |133.04166666666666|268     |-39     |88.19764325288017 |0                 |114.5             |333      |-85      |103.5533888765891 |0                  |98.91666666666667|309      |-78      |88.87211949305815 |0                  |70.375            |289      |-90      |84.85937856498116 |0                  |93.125            |318      |-134     |101.89265984571598|0                  |91.20833333333333 |235      |-43      |80.12543382052627|0                  |51.291666666666664|242      |-147     |111.09865540088259|0                  |103.0            |275      |-174     |126.789452311268  |0                  |108.83333333333333|391      |-177     |126.73857607952942|0                  |98.54166666666667 |273      |-96      |93.45632747400006 |0                  |70.75             |292      |-80      |110.19044778295756|0                  |90.91666666666667 |406      |-50      |111.57135235653759|0                  |2024-12-01          |24          |23        |2023-01-01         |2025-05-18 11:38:06.073492|
# +-----------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+--------+--------+------------------+------------------+------------------+---------+---------+------------------+-------------------+-----------------+---------+---------+------------------+-------------------+------------------+---------+---------+------------------+-------------------+------------------+---------+---------+------------------+-------------------+------------------+---------+---------+-----------------+-------------------+------------------+---------+---------+------------------+-------------------+-----------------+---------+---------+------------------+-------------------+------------------+---------+---------+------------------+-------------------+------------------+---------+---------+------------------+-------------------+------------------+---------+---------+------------------+-------------------+------------------+---------+---------+------------------+-------------------+--------------------+------------+----------+-------------------+--------------------------+
# only showing top 5 rows
#
#
# Silver层验证完成!
